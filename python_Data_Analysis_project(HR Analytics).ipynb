# %% [markdown]
# <h1><font color="green">python Data Analysis project(HR Analytics)<font/><h1/>

# %%
# required module numpy,pandas matplotlib seaborn
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading dataframes
train=pd.read_csv("trainhr.csv")
test=pd.read_csv("testhr.csv")

# %%
# getting their shapes
print("Shapes of train dataset",train.shape)
print("Shape of test dataset",test.shape)
# Out:
# Shapes of train dataset (54808, 14)
# Shape of test dataset (23490, 13)

# %%
# getting the head of train and testdataset

# pd.set_option('display.max_rows',120)
pd.set_option('display.max_columns',50)
pd.set_option('display.max_colwidth',50)
pd.set_option('display.width',500)
test.head(2)
# print(test.head(),train.head(),sep="\n")
# Out:
#    employee_id  department     region   education gender recruitment_channel  no_of_trainings  age  previous_year_rating  length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0         8724  Technology  region_26  Bachelor's      m            sourcing                1   24                   NaN                  1              1            0                  77
# 1        74430          HR   region_4  Bachelor's      f               other                1   31                   3.0                  5              0            0                  51

# %%
train.head(2)
# Out:
#    employee_id         department     region         education gender recruitment_channel  no_of_trainings  age  previous_year_rating  length_of_service  KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# 0        65438  Sales & Marketing   region_7  Master's & above      f            sourcing                1   35                   5.0                  8              1            0                  49            0
# 1        65141         Operations  region_22        Bachelor's      m               other                1   30                   5.0                  4              0            0                  60            0

# %%
# describing train dataset
train.describe(include="all")
# Out:
#          employee_id         department    region   education gender recruitment_channel  no_of_trainings           age  previous_year_rating  length_of_service  KPIs_met >80%   awards_won?  avg_training_score   is_promoted
# count   54808.000000              54808     54808       52399  54808               54808     54808.000000  54808.000000          50684.000000       54808.000000   54808.000000  54808.000000        54808.000000  54808.000000
# unique           NaN                  9        34           3      2                   3              NaN           NaN                   NaN                NaN            NaN           NaN                 NaN           NaN
# top              NaN  Sales & Marketing  region_2  Bachelor's      m               other              NaN           NaN                   NaN                NaN            NaN           NaN                 NaN           NaN
# ...

# %%
# getting information about train dataset
train.info()
# test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
# checking null values in dataset
train.isnull().any()
# Out:
# employee_id             False
# department              False
# region                  False
# education                True
# gender                  False
# recruitment_channel     False
# no_of_trainings         False
# age                     False
# previous_year_rating     True
# length_of_service       False
# KPIs_met >80%           False
# awards_won?             False
# avg_training_score      False
# is_promoted             False
# dtype: bool

# %%
# counting null values in dataset
train.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
# getting the name of columns
train.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender', 'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service', 'KPIs_met >80%', 'awards_won?', 'avg_training_score', 'is_promoted'], dtype='object')

# %%
train[["employee_id","department","education","recruitment_channel"]]
# Out:
#        employee_id         department         education recruitment_channel
# 0            65438  Sales & Marketing  Master's & above            sourcing
# 1            65141         Operations        Bachelor's               other
# 2             7513  Sales & Marketing        Bachelor's            sourcing
# 3             2542  Sales & Marketing        Bachelor's               other
# 4            48945         Technology        Bachelor's               other
# ...            ...                ...               ...                 ...
# 54803         3030         Technology        Bachelor's            sourcing
# 54804        74592         Operations  Master's & above               other
# 54805        13918          Analytics        Bachelor's               other
# 54806        13614  Sales & Marketing               NaN            sourcing
# 54807        51526                 HR        Bachelor's               other
#
# [54808 rows x 4 columns]

# %% [markdown]
# # UNI Variable data visualization

# %%
# finding out most popular department
train.groupby("department")["department"].count()
# Out:
# department
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# Operations           11348
# Procurement           7138
# R&D                    999
# Sales & Marketing    16840
# Technology            7138
# Name: department, dtype: int64

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopword=set(STOPWORDS).add("dtype")
# print(stopword)
print(stopword)
wordcloud=WordCloud(background_color="pink",stopwords=stopword).generate(str(train['department']))
plt.rcParams["figure.figsize"]=(12,8)
print(wordcloud)
plt.imshow(wordcloud)
plt.title("Most Popular Department",fontsize=35)
plt.axis(False)
plt.show()
# Out:
# None
# ...

# %%
train.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender', 'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service', 'KPIs_met >80%', 'awards_won?', 'avg_training_score', 'is_promoted'], dtype='object')

# %%
#  no of employees promoted
res=train['is_promoted'].value_counts()
total=train['is_promoted'].count()
notpromoted=res[0]
promoted=res[1]
print(notpromoted,promoted)
# Out:
# 50140 4668

# %%
# finding th $age of employees promoted
proper=(promoted/total)*100
print("Percentage of promoted employees is: {:.2f}%".format(proper))
# Out:
# Percentage of promoted employees is: 8.52%

# %%
#plotting a sctter plot

plt.hist(train['is_promoted'])
plt.title("plot to show gap in promoted and non-promoted employees",fontsize=30)
plt.xlabel('0-non promoted   and  1-promotes',fontsize=20)
plt.grid()
plt.ylabel('count')
plt.show()

# %%
#dist of avg training score

plt.rcParams['figure.figsize']=(15,7)
sns.histplot(train['avg_training_score'],color='cyan')
plt.title('dist of avg training score',fontsize=30)
plt.xlabel('Avg training score')
plt.ylabel('count')
plt.show()

# %%
# counting the number of employees who have won the award
res=train['awards_won?'].value_counts()
size=[res[0],res[1]]
exp=[0,.2]
color=['red','green']
lables=['No Award Won','Award Won']
plt.pie(size,colors=color,autopct='%0.2f%%',labels=lables,radius=.8,explode=exp)
plt.title("Showing % of employees who won award",fontsize=20)
plt.show()

# %%
# checking the distribution of length of service
sns.distplot(train['length_of_service'],color='navy')
plt.title('checking the distribution of length of service',fontsize=30)
plt.xlabel("Length of service in years",fontsize=15)
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\mahbo\AppData\Local\Temp\ipykernel_17164\162411236.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['length_of_service'],color='navy')

# %%
# checking the distribution of age of employees of company

sns.distplot(train['age'],color='pink')
plt.title('checking the distribution of age of employees',fontsize=30)
plt.xlabel("age ",fontsize=15)
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\mahbo\AppData\Local\Temp\ipykernel_17164\766254313.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['age'],color='pink')

# %%
# checking the different type of recuritment channel for the company
res=train['recruitment_channel'].value_counts()
size=[res['other'],res['sourcing'],res['referred']]
color=["red","green","blue"]
labels=["others","sourcing","reffered"]


plt.rcParams['figure.figsize']=(9,9)
plt.pie(size,colors=color,labels=labels,shadow=True,autopct="%0.2f%%")
plt.title("Showing share of different recuritment channels",fontsize=30)
my_circle=plt.Circle((0,0),0.7,color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.legend()
plt.show()
# print(size)
